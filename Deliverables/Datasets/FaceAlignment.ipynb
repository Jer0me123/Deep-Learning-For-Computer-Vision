# %% [markdown]
# # Face Alignment
#
# This notebook when run goes through every image in the specifed directories and using the MTCNN face detector detects and alignes faces.

# %%
import os
import cv2
import numpy as np
from mtcnn import MTCNN
from PIL import Image

# Initialise MTCNN detector
detector = MTCNN()

def align_face(image_path):
    """ Detects, aligns, and rotates face from an image using MTCNN. Overwrites the image if a face is found. """
    try:
        img = cv2.imread(image_path)
        if img is None:
            print(f"Skipping {image_path}, unable to read image.")
            return
        
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
        original_size = (img.shape[1], img.shape[0]) 
        detections = detector.detect_faces(img_rgb)
        
        if detections:
            for detection in detections:
                if detection['confidence'] > 0.90:  
                    x, y, width, height = detection['box']
                    x, y = max(0, x), max(0, y) 
                    face = img_rgb[y:y+height, x:x+width]  
                    
                    # Get facial landmarks
                    keypoints = detection['keypoints']
                    left_eye = keypoints['left_eye']
                    right_eye = keypoints['right_eye']

                    # Convert to integers (fix TypeError)
                    left_eye = (int(left_eye[0]), int(left_eye[1]))
                    right_eye = (int(right_eye[0]), int(right_eye[1]))

                    # Compute angle to align the eyes
                    dx = right_eye[0] - left_eye[0]
                    dy = right_eye[1] - left_eye[1]
                    angle = np.degrees(np.arctan2(dy, dx))

                    # Rotate the image around the center of the eyes
                    center = ((left_eye[0] + right_eye[0]) // 2, (left_eye[1] + right_eye[1]) // 2)
                    rot_matrix = cv2.getRotationMatrix2D(center, angle, 1.0)
                    aligned_img = cv2.warpAffine(img_rgb, rot_matrix, (img.shape[1], img.shape[0]))

                    # Crop face again after rotation
                    aligned_face = aligned_img[y:y+height, x:x+width]

                    # Convert to PIL Image for resizing
                    face_pil = Image.fromarray(aligned_face)
                    face_pil = face_pil.resize(original_size) 
                    
                    # Save aligned face (overwrite original image)
                    face_pil.save(image_path)
                    print(f"Aligned and saved: {image_path}")
                    return 
        
    except Exception as e:
        print(f"Error processing {image_path}: {e}")

def process_directory(directory):
    """ Recursively processes all images in the given directory and its subdirectories. """
    for root, _, files in os.walk(directory):
        for file in files:
            if file.lower().endswith(('.png', '.jpg', '.jpeg')):
                image_path = os.path.join(root, file)
                align_face(image_path)

# %%
# Set input directory
input_dirs = ['AffectNet_Structured_Aligned', 'CK+_Structured_Aligned', 'FER_Structured_Aligned', 'RAF-DB_Structured_Aligned', 'JAFFE_Structured_Aligned']

for input_dir in input_dirs:
    if not os.path.exists(input_dir):
        print(f"Directory {input_dir} does not exist. Skipping.")
        continue
    print(f"Processing directory: {input_dir}")
    process_directory(input_dir)
# Out:
# Processing directory: AffectNet_Test
# Aligned and saved: AffectNet_Test\test\test_0_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1000_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1001_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1002_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1003_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1004_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1005_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1006_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1007_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1008_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1009_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_100_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1010_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1011_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1012_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1013_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1014_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1015_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1016_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1017_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1018_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1019_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_101_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1020_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1021_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1022_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1023_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1024_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1025_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1026_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1027_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1029_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_102_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1030_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1031_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1032_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1033_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1034_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1035_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1036_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1037_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1038_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1039_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_103_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1040_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1041_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1042_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1043_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1044_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1045_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1046_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1048_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1049_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_104_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1050_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1051_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1052_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1053_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1054_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1055_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1056_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1057_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1058_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1059_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_105_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1060_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1061_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1062_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1063_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1064_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1065_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1066_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1068_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1069_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_106_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1070_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1071_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1072_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1073_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1074_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1075_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1076_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1077_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1078_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1079_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_107_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1080_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1081_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1082_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1083_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1084_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1085_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1086_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1087_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1088_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1089_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_108_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1090_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1091_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1092_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1093_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1094_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1095_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1096_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1097_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1098_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1099_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_109_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_10_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1100_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1101_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1102_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1103_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1104_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1105_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1106_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1107_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1108_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1109_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_110_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1110_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1111_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1113_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1114_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1115_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1116_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1117_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1118_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1119_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_111_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1120_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1121_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1122_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1123_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1124_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1125_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1126_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1127_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1128_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1129_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_112_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1130_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1131_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1132_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1133_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1134_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1135_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1136_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1137_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1138_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1139_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_113_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1140_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1141_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1142_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1143_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1144_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1145_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1146_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1147_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1148_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_114_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1150_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1151_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1152_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1153_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1154_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1155_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1156_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1157_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1158_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1159_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_115_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1160_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1161_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1162_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1163_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1165_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1166_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1167_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1168_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1169_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_116_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1170_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1171_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1172_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1173_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1174_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1175_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1176_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1177_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1178_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1179_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_117_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1180_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1181_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1182_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1183_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1184_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1186_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1187_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1188_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1189_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_118_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1190_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1192_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1193_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1194_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1195_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1196_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1197_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1198_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_1199_Fear.jpg
# Aligned and saved: AffectNet_Test\test\test_119_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_11_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1200_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1201_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1202_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1203_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1204_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1205_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1206_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1207_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1208_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1209_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_120_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1210_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1211_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1212_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1213_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1214_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1215_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1216_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1217_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1218_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1219_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_121_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1220_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1221_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1222_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1223_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1224_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1225_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1226_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1227_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1228_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1229_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_122_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1230_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1232_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1233_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1234_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1235_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1236_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1237_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1238_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1239_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_123_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1240_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1241_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1242_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1243_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1244_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1245_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1246_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1247_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1249_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_124_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1250_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1251_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1252_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1253_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1254_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1255_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1256_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1257_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1258_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1259_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_125_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1260_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1261_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1262_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1263_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1264_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1265_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1266_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1267_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1268_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1269_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_126_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1270_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1271_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1272_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1273_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1274_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1275_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1276_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1277_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1278_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1279_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_127_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1280_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1282_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1283_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1284_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1285_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1286_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1287_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1288_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1289_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_128_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1290_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1291_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1292_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1293_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1294_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1295_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1296_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1297_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1298_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1299_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_129_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_12_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1300_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1301_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1302_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1303_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1304_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1305_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1306_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1307_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1308_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1309_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_130_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1310_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1311_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1312_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1313_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1314_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1315_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1316_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1317_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1318_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1319_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_131_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1320_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1321_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1322_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1323_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1324_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1325_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1326_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1327_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1328_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1329_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_132_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1330_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1331_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1332_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1333_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1334_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1335_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1336_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1337_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1338_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1339_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_133_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1340_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1341_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1342_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1343_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1344_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1345_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1346_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1347_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1348_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1349_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_134_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1351_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1352_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1353_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1354_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1355_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1356_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1357_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1358_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1359_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_135_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1360_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1361_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1362_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1363_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1364_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1365_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1366_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1367_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1368_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1369_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_136_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1370_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1371_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1372_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1373_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1374_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1376_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1377_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1378_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1379_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_137_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1380_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1381_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1382_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1383_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1385_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1386_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1387_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1388_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1389_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_138_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1390_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1391_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1392_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1393_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1394_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1395_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1396_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1397_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1398_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1399_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_139_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_13_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1400_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1401_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1402_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1403_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1404_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1405_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1406_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1407_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1408_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1409_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_140_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1410_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1411_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1412_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1413_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1414_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1415_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1417_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1418_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_141_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1420_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1421_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1422_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1423_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1424_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1425_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1426_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1427_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1428_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1429_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1430_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1431_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1432_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1433_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1434_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1435_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1436_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1437_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1438_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1439_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_143_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1440_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1441_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1442_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1443_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1444_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1445_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1446_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1447_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1448_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1449_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_144_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1450_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1451_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1452_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1453_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1454_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1455_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1456_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1457_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1458_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1459_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_145_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1460_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1461_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1462_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1463_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1464_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1465_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1466_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1467_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1468_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1469_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_146_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1470_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1471_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1472_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1473_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1474_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1475_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1476_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1477_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1478_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1479_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_147_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1480_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1482_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1483_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1484_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1485_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1486_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1487_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1488_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1489_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_148_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1490_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1491_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1492_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1493_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1494_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1495_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1496_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1497_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1498_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1499_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_149_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_14_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1500_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1501_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1502_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1503_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1504_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1505_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1506_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1507_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1508_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1509_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_150_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1510_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1511_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1512_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1513_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1514_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1515_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1516_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1517_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1518_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1519_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_151_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1520_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1521_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1522_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1523_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1524_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1525_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1526_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1527_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1528_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1529_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_152_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1530_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1531_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1532_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1533_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1534_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1535_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1536_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1537_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1538_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1539_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_153_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1540_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1541_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1542_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1543_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1544_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1545_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1547_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1548_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1549_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_154_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1550_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1551_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1552_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1553_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1554_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1555_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1556_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1558_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1559_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_155_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1561_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1562_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1563_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1564_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1565_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1566_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1567_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1568_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1569_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_156_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1571_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1572_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1573_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1574_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1575_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1576_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1577_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1578_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1579_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_157_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1580_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1581_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1582_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1583_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1584_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1585_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1586_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1587_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1588_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1589_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_158_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1590_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1591_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1592_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1593_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1594_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1595_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1596_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1597_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1598_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_1599_Happy.jpg
# Aligned and saved: AffectNet_Test\test\test_159_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_15_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1600_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1601_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1602_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1603_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1604_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1605_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1606_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1607_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1608_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1609_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_160_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1610_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1611_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1612_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1613_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1614_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1615_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1616_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1617_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1618_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1619_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_161_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1620_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1621_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1622_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1623_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1624_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1625_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1626_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1627_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1628_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1629_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_162_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1630_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1631_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1632_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1634_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1635_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1636_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1637_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1638_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1639_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_163_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1640_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1641_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1642_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1643_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1644_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1645_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1646_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1647_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1648_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1649_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_164_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1650_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1651_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1652_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1653_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1654_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1655_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1656_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1657_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1658_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1659_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_165_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1660_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1661_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1662_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1663_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1664_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1665_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1666_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1667_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1668_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1669_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_166_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1670_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1671_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1672_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1673_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1674_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1675_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1676_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1677_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1678_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_167_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1680_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1681_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1682_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1683_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1684_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1685_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1686_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1687_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1688_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1689_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_168_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1690_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1691_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1693_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1694_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1696_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1697_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1698_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1699_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_169_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_16_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1700_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1701_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1702_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1703_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1704_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1705_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1706_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1707_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1708_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1709_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_170_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1710_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1711_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1712_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1713_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1714_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1715_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1716_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1717_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1718_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1719_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_171_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1720_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1721_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1722_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1723_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1724_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1725_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1726_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1727_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1728_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1729_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_172_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1730_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1731_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1732_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1733_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1734_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1735_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1736_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1737_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1738_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1739_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_173_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1740_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1741_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1742_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1743_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1744_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1745_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1746_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1747_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1748_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1749_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_174_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1750_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1751_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1752_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1753_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1754_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1755_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1756_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1757_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1758_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1759_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_175_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_1760_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1761_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1762_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1763_Sad.jpg
# Aligned and saved: AffectNet_Test\test\test_1764_Sad.jpg
# ...
# Aligned and saved: AffectNet_Test\test\test_2224_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2225_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2226_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2227_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2228_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2229_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_222_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_2230_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2231_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2232_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2233_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2234_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2235_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2236_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2237_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2238_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2239_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_223_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_2240_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2241_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2242_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2243_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2244_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2245_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2246_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2247_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2248_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2249_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_224_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_2250_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2251_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2252_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2253_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2254_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2255_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2256_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2257_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2258_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2259_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_225_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_2260_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2261_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2262_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2263_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2264_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2265_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2266_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2267_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2268_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2269_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_226_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_2270_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2271_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2272_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2273_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2274_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2275_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2276_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2277_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2279_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_227_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_2280_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2281_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2282_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2283_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2284_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2285_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2286_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2287_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2288_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2289_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_228_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_2290_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2291_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2294_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2295_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2296_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2297_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2298_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2299_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_229_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_2300_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2301_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2302_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2303_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2304_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2305_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2306_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2307_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2308_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2309_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_230_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_2310_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2311_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2312_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2313_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2314_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2315_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2316_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2317_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2318_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_231_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_2320_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2321_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2322_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2323_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2324_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2325_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2326_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2327_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2328_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2329_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_232_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_2331_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2332_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2333_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2334_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2335_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2336_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2337_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2338_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2339_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_233_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_2340_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2342_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2343_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2344_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2345_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2346_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2347_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2349_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_234_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_2350_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2351_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2352_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2353_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2354_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2355_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2356_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2357_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2358_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2359_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_235_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_2360_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2361_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2362_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2363_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2364_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2365_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2366_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2367_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2368_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2369_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_236_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_2370_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2371_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2372_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2373_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2374_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2375_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2376_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2377_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2378_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2379_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_237_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_2380_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2381_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2382_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2383_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2384_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2385_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2386_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2387_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2388_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2389_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_238_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_2390_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2391_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2392_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2393_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2394_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2395_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2396_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2397_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2398_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_2399_Surprise.jpg
# Aligned and saved: AffectNet_Test\test\test_239_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_23_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_2400_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2401_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2402_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2403_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2404_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2405_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2406_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2407_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2408_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2409_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_240_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_2410_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2411_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2412_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2413_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2414_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2415_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2416_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2417_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2418_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2419_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_241_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_2421_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2422_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2423_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2424_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2425_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2426_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2427_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2428_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2429_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_242_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_2430_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2431_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2432_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2433_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2434_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2435_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2436_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2437_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2438_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2439_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_243_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_2440_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2441_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2442_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2443_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2444_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2445_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2446_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2447_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2448_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2449_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_244_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_2451_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2452_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2453_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2454_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2455_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2456_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2457_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2458_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2459_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_245_Angry.jpg
# Aligned and saved: AffectNet_Test\test\test_2460_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2461_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2462_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2464_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2465_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2466_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2467_Neutral.jpg
# Aligned and saved: AffectNet_Test\test\test_2468_Neutral.jpg
