# %%
import os
import pandas as pd
import numpy as np
from PIL import Image
from sklearn.model_selection import train_test_split
import shutil

# %%
# The RAF-DB labels are not aligned with the universal emotion labels
RAF_DB_Label_Mapping = {1:'surprise', 2:'fear', 3:'disgust', 4:'happy', 5:'sad', 6:'angry', 7:'neutral'}
universal_emotion_mapping = {0: 'Angry', 1: 'Disgust', 2: 'Fear', 3: 'Happy', 4: 'Sad', 5: 'Surprise', 6: 'Neutral'}

# This aligns the mapping of the RAF-DB labels with the universal emotion labels
Updated_RAF_DB_Label_Mapping = {1:5, 2:2, 3:1, 4:3, 5:4, 6:0, 7:6}

# %%
def process_split(base_dir, rafdb_root, original_dir, split_name, target_dir, df=None):
    """
    Process a dataset split and create labels CSV
    original_dir: Path to original RAF-DB images (train/test)
    split_name: Prefix for filenames (train/val/test)
    target_dir: Output directory
    df: DataFrame containing labels (for test split)
    """
    os.makedirs(os.path.join(base_dir, target_dir), exist_ok=True)
    labels = []

    # For test split (validation/test), use integer labels
    if df is not None:
        for idx, row in df.iterrows():
            label = row['label']
            emotion = RAF_DB_Label_Mapping[int(label)]
            orig_path = os.path.join(rafdb_root, "DATASET", original_dir, str(label), row['image'])
            
            img = Image.open(orig_path)
            filename = f"{split_name}_{idx}_{emotion}.png"
            img.save(os.path.join(base_dir, target_dir, filename))
            
            # Store INTEGER label for validation/test
            labels.append({'filename': filename, 'label': Updated_RAF_DB_Label_Mapping[int(label)]})

    # For train split, keep emotion names in CSV
    else:
        idx = 0
        for label in os.listdir(os.path.join(rafdb_root, "DATASET", original_dir)):
            label_dir = os.path.join(rafdb_root, "DATASET", original_dir, label)
            if not os.path.isdir(label_dir):
                continue

            for img_file in os.listdir(label_dir):
                emotion = RAF_DB_Label_Mapping[int(label)]
                orig_path = os.path.join(label_dir, img_file)
                
                img = Image.open(orig_path)
                filename = f"{split_name}_{idx}_{emotion}.png"
                img.save(os.path.join(base_dir, target_dir, filename))
                
                # Store TEXT label for training
                labels.append({'filename': filename, 'label': Updated_RAF_DB_Label_Mapping[int(label)]})
                idx += 1

    # Order the entries and save labels CSV
    labels = pd.DataFrame(labels)
    labels['sort_key'] = labels['filename'].str.extract(r'_(\d+)_').astype(int)
    labels = labels.sort_values('sort_key').drop(columns='sort_key')

    pd.DataFrame(labels).to_csv(os.path.join(base_dir, target_dir, "labels.csv"), index=False)

# %%
def copy_images_to_label_subdirectories(base_dir):
    """
    For each subdirectory (test, train, validation) in base_dir,
    copy images into subdirectories based on their label, extracted from the filename.
    
    Expected filename format: {usecase}_{index}_{label}.{ext}
    """
    # Define the usage folders.
    usage_dirs = ['train', 'test', 'validation']
    
    for usage in usage_dirs:
        usage_path = os.path.join(base_dir, usage)
        if not os.path.isdir(usage_path):
            print(f"Directory {usage_path} does not exist. Skipping.")
            continue
        
        # Process each file in the usage folder.
        for filename in os.listdir(usage_path):
            file_path = os.path.join(usage_path, filename)
            if os.path.isfile(file_path):
                # Parse the filename. We expect at least 3 parts separated by '_'
                parts = filename.split('_')
                if len(parts) < 3:
                    print(f"Filename {filename} does not match expected format. Skipping.")
                    continue
                
                # The label is assumed to be the last part, with the file extension removed.
                label_with_ext = parts[-1]
                label, _ = os.path.splitext(label_with_ext)
                
                # Create the label subdirectory if it doesn't exist.
                label_dir = os.path.join(usage_path, label)
                os.makedirs(label_dir, exist_ok=True)
                
                # Copy the image into the label subdirectory.
                destination_file_path = os.path.join(label_dir, filename)
                shutil.copy2(file_path, destination_file_path)

# %%
# Define paths and structure
rafdb_root = "RAF-DB" # Where the original dataset is stored
base_dir = "RAFDB_Structured_2" # Where you want the structured dataset to be saved
os.makedirs(base_dir, exist_ok=True)

# Process training set
process_split(base_dir, rafdb_root, "train", "train", "train")

# Process test set with stratified split
test_labels = pd.read_csv(os.path.join(rafdb_root, "test_labels.csv"))
train_labels = pd.read_csv(os.path.join(rafdb_root, "train_labels.csv"))

# Stratified split of test set into validation/test (50/50)
val_df, test_df = train_test_split(
    test_labels,
    test_size=0.5,
    stratify=test_labels['label'],
    random_state=42
)

# Create validation set (uses integer labels in CSV)
process_split(base_dir, rafdb_root, "test", "val", "validation", val_df)

# Create test set (uses integer labels in CSV)
process_split(base_dir, rafdb_root, "test", "test", "test", test_df)

print("Dataset restructuring complete!")

# Set the base directory containing the train, test, and validation subdirectories.
base_directory = 'RAF-DB_Structured'
copy_images_to_label_subdirectories(base_directory)
# Out:
# Dataset restructuring complete!
# Filename labels.csv does not match expected format. Skipping.
# Filename labels.csv does not match expected format. Skipping.
# Filename labels.csv does not match expected format. Skipping.

# %%
# import os
# import shutil
# import pandas as pd
# import random
# from collections import defaultdict

# def organize_rafdb(dataset_path, output_path, train_ratio=0.6, val_ratio=0.2, test_ratio=0.2):
#     label_mapping = {1: "Surprised", 2: "Fear", 3: "Disgust", 4: "Happy", 5: "Sad", 6: "Angry", 7: "Neutral"}

#     assert train_ratio + val_ratio + test_ratio == 1.0, "Ratios must sum to 1.0"
    
#     # Load label data
#     train_labels = pd.read_csv(os.path.join(dataset_path, "train_labels.csv"))
#     test_labels = pd.read_csv(os.path.join(dataset_path, "test_labels.csv"))
    
#     all_labels = pd.concat([train_labels, test_labels], ignore_index=True)
#     all_labels.columns = ["image", "label"]
    
#     # Prepare directories
#     for split in ['train', 'validation', 'test']:
#         split_path = os.path.join(output_path, split)
#         os.makedirs(split_path, exist_ok=True)
    
#     # Full image paths
#     image_paths = []
#     for root, _, files in os.walk(os.path.join(dataset_path, "DATASET")):
#         for file in files:
#             if file.endswith(".jpg"):
#                 image_paths.append(os.path.join(root, file))
    
#     # Map image names to paths
#     image_dict = {os.path.basename(path): path for path in image_paths}
    
#     # Filter available images
#     all_labels = all_labels[all_labels["image"].isin(image_dict.keys())]

#     # Group by label
#     emotion_groups = defaultdict(list)
#     for _, row in all_labels.iterrows():
#         emotion_groups[row["label"]].append(row)
    
#     # Stratified splitting
#     train_files, val_files, test_files = [], [], []
    
#     for emotion, files in emotion_groups.items():
#         random.shuffle(files)
#         n = len(files)
#         train_end = int(n * train_ratio)
#         val_end = train_end + int(n * val_ratio)
        
#         train_files.extend(files[:train_end])
#         val_files.extend(files[train_end:val_end])
#         test_files.extend(files[val_end:])
    
#     # Function to copy images
#     def copy_images(data, split):
#         for cnt, row in enumerate(data):
#             image_name = row["image"]
#             label = row["label"]
#             src_path = image_dict[image_name]
#             new_name = f"{split}_{cnt}_{label_mapping[label]}.jpg"
#             dest_path = os.path.join(output_path, split, new_name)
#             shutil.copy(src_path, dest_path)
    
#     # Copy images to their respective directories
#     copy_images(train_files, "train")
#     copy_images(val_files, "validation")
#     copy_images(test_files, "test")
    
#     print("Dataset organized successfully!")

# # Example usage
# dataset_path = "RAF-DB"
# dataset_output_path = "RAF-DB_ResEmoteNet"
# organize_rafdb(dataset_path, dataset_output_path, train_ratio=0.8, val_ratio=0.1, test_ratio=0.1)

# %% [markdown]
# ### Preparing RAF-DB Data - ResEmoteNet Format - Equal Class Distribution - Data Augmentation (Low Quantity Labels)

# %%
# import os
# import shutil
# import pandas as pd
# import random
# from collections import defaultdict

# def organize_rafdb(dataset_path, output_path, train_ratio=0.7, val_ratio=0.15, test_ratio=0.15):
#     assert train_ratio + val_ratio + test_ratio == 1.0, "Ratios must sum to 1.0"

#     # Load label data
#     train_labels = pd.read_csv(os.path.join(dataset_path, "train_labels.csv"))
#     test_labels = pd.read_csv(os.path.join(dataset_path, "test_labels.csv"))

#     all_labels = pd.concat([train_labels, test_labels], ignore_index=True)
#     all_labels.columns = ["image", "label"]

#     # Prepare directories
#     for split in ['train', 'validation', 'test']:
#         os.makedirs(os.path.join(output_path, split), exist_ok=True)

#     # Full image paths
#     image_paths = {os.path.basename(path): path for path in 
#                    [os.path.join(root, file) 
#                     for root, _, files in os.walk(os.path.join(dataset_path, "DATASET")) 
#                     for file in files if file.endswith(".jpg")]}

#     # Filter available images
#     all_labels = all_labels[all_labels["image"].isin(image_paths.keys())]

#     # Group images by label
#     emotion_groups = defaultdict(list)
#     for _, row in all_labels.iterrows():
#         emotion_groups[row["label"]].append(row)

#     # Stratified sampling: Ensure equal distribution across splits
#     train_files, val_files, test_files = [], [], []

#     for label, files in emotion_groups.items():
#         random.shuffle(files)  # Shuffle each label group
#         n = len(files)
#         train_end = int(n * train_ratio)
#         val_end = train_end + int(n * val_ratio)

#         train_files.extend(files[:train_end])
#         val_files.extend(files[train_end:val_end])
#         test_files.extend(files[val_end:])

#     # Function to copy images to respective directories
#     def copy_images(data, split):
#         for _, row in data.iterrows():
#             image_name = row["image"]
#             label = row["label"]
#             src_path = image_paths[image_name]
#             new_name = f"{split}_{os.path.splitext(image_name)[0]}_{label}.jpg"
#             dest_path = os.path.join(output_path, split, new_name)
#             shutil.copy(src_path, dest_path)

#     # Copy images to their respective directories
#     copy_images(pd.DataFrame(train_files), "train")
#     copy_images(pd.DataFrame(val_files), "validation")
#     copy_images(pd.DataFrame(test_files), "test")

#     # Display label distribution in each directory
#     def display_distribution(data, split):
#         label_counts = pd.DataFrame(data)["label"].value_counts().sort_index()
#         total = len(data)
#         percentages = (label_counts / total * 100).round(2)
#         distribution = pd.DataFrame({"Count": label_counts, "Percentage": percentages})
#         print(f"\nLabel distribution in {split} set:")
#         print(distribution)
    
#     display_distribution(train_files, "train")
#     display_distribution(val_files, "validation")
#     display_distribution(test_files, "test")

#     print("\nDataset organized successfully!")

# # Example usage
# dataset_path = "RAF-DB"
# dataset_output_path = "RAF-DB_ResEmoteNet"
# organize_rafdb(dataset_path, dataset_output_path, train_ratio=0.8, val_ratio=0.1, test_ratio=0.1)

# %%
# import os
# import shutil
# import pandas as pd
# import random
# import numpy as np 
# import albumentations as A
# from albumentations.pytorch import ToTensorV2
# from collections import defaultdict
# from sklearn.utils.class_weight import compute_class_weight
# import cv2
# import matplotlib.pyplot as plt

# def organize_rafdb(dataset_path, output_path, train_ratio=0.7, val_ratio=0.15, test_ratio=0.15):
#     assert train_ratio + val_ratio + test_ratio == 1.0, "Ratios must sum to 1.0"

#     label_mapping = {1: "Surprised", 2: "Fear", 3: "Disgust", 4: "Happy", 5: "Sad", 6: "Angry", 7: "Neutral"}

#     # Load label data
#     train_labels = pd.read_csv(os.path.join(dataset_path, "train_labels.csv"))
#     test_labels = pd.read_csv(os.path.join(dataset_path, "test_labels.csv"))

#     all_labels = pd.concat([train_labels, test_labels], ignore_index=True)
#     all_labels.columns = ["image", "label"]

#     # Prepare directories
#     for split in ['train', 'validation', 'test']:
#         os.makedirs(os.path.join(output_path, split), exist_ok=True)

#     # Full image paths
#     image_paths = {os.path.basename(path): path for path in 
#                    [os.path.join(root, file) 
#                     for root, _, files in os.walk(os.path.join(dataset_path, "DATASET")) 
#                     for file in files if file.endswith(".jpg")]}

#     # Filter available images
#     all_labels = all_labels[all_labels["image"].isin(image_paths.keys())]

#     # Group images by label
#     emotion_groups = defaultdict(list)
#     for _, row in all_labels.iterrows():
#         emotion_groups[row["label"]].append(row)

#     # Stratified sampling: Ensure equal distribution across splits
#     train_files, val_files, test_files = [], [], []

#     for label, files in emotion_groups.items():
#         random.shuffle(files)  # Shuffle each label group
#         n = len(files)
#         train_end = int(n * train_ratio)
#         val_end = train_end + int(n * val_ratio)

#         train_files.extend(files[:train_end])
#         val_files.extend(files[train_end:val_end])
#         test_files.extend(files[val_end:])

#     # # Compute class weights for training
#     # train_labels_list = [row["label"] for row in train_files]
#     # unique_classes = np.array(sorted(set(train_labels_list))) 
#     # class_weights = compute_class_weight(
#     #     class_weight="balanced",
#     #     classes=unique_classes, 
#     #     y=train_labels_list
#     # )
#     # class_weights_dict = {i: weight for i, weight in zip(unique_classes, class_weights)}
#     # print("\nComputed Class Weights:", class_weights_dict)

#     # Define augmentation for minority classes (adjust labels as needed)
#     augmentation = A.Compose([
#         A.RandomRotate90(),
#         A.HorizontalFlip(),
#         A.ColorJitter(),
#         ToTensorV2()
#     ])

#     # Function to copy and augment images
#     def copy_images(data, split):
#         for index, row in data.iterrows():
#             image_name = row["image"]
#             label = row["label"]
#             src_path = image_paths[image_name]
#             new_name = f"{split}_{index}_{label_mapping[label]}.jpg"
#             dest_path = os.path.join(output_path, split, new_name)
            
#             # Read image using OpenCV (install with: pip install opencv-python)
#             image = cv2.imread(src_path)
#             image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert to RGB
            
#             # Apply augmentation only to minority classes - Update this to auto select based on distribution
#             if label in [2, 3, 6]:  # Example minority classes
#                 augmented = augmentation(image=image)
#                 augmented_image = augmented["image"].numpy().transpose(1, 2, 0)
#                 cv2.imwrite(dest_path, cv2.cvtColor(augmented_image, cv2.COLOR_RGB2BGR))
#             else:
#                 # Directly copy without augmentation
#                 shutil.copy(src_path, dest_path)

#     # Copy images to their respective directories
#     copy_images(pd.DataFrame(train_files), "train")
#     copy_images(pd.DataFrame(val_files), "validation")
#     copy_images(pd.DataFrame(test_files), "test")

#     # Display label distribution in each directory
#     def display_distribution(data, split):
#         label_counts = pd.DataFrame(data)["label"].value_counts().sort_index()
#         total = len(data)
#         percentages = (label_counts / total * 100).round(2)
#         distribution = pd.DataFrame({"Count": label_counts, "Percentage": percentages})
#         print(f"\nLabel distribution in {split} set:")
#         print(distribution)
    
#     display_distribution(train_files, "train")
#     display_distribution(val_files, "validation")
#     display_distribution(test_files, "test")

#     print("\nDataset organized successfully!")

# # Example usage
# dataset_path = "RAF-DB"
# dataset_output_path = "RAF-DB_ResEmoteNet"
# organize_rafdb(dataset_path, dataset_output_path, train_ratio=0.8, val_ratio=0.1, test_ratio=0.1)
# Out:
# Label distribution in train set:
#        Count  Percentage
# label
# 1       1295       10.56
# 2        284        2.31
# 3        701        5.71
# 4       4765       38.84
# 5       1968       16.04
# 6        693        5.65
# 7       2563       20.89
#
# Label distribution in validation set:
#        Count  Percentage
# label
# 1        161       10.52
# 2         35        2.29
# 3         87        5.69
# 4        595       38.89
# 5        246       16.08
# 6         86        5.62
# 7        320       20.92
#
# Label distribution in test set:
#        Count  Percentage
# label
# 1        163       10.58
# 2         36        2.34
# 3         89        5.78
# 4        597       38.77
# 5        246       15.97
# 6         88        5.71
# 7        321       20.84
#
# Dataset organized successfully!

# %% [markdown]
# ### Convert To GrayScale

# %%
# import os
# import cv2

# def convert_to_grayscale(input_dir):
#     """
#     Converts all images in a directory to grayscale and saves them in a new directory.
    
#     Args:
#         input_dir (str): Path to directory containing images
#     """
#     # Create output directory path
#     base_dir = os.path.dirname(input_dir)
#     dir_name = os.path.basename(input_dir)
#     output_dir = os.path.join(base_dir, f"{dir_name}_grayscale")
    
#     # Create output directory if it doesn't exist
#     os.makedirs(output_dir, exist_ok=True)
    
#     # Supported image extensions
#     valid_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tif', '.tiff')
    
#     # Process all files
#     for root, dirs, files in os.walk(input_dir):
#         for file in files:
#             if file.lower().endswith(valid_extensions):
#                 # Create input and output paths
#                 input_path = os.path.join(root, file)
#                 relative_path = os.path.relpath(root, input_dir)
#                 output_subdir = os.path.join(output_dir, relative_path)
                
#                 # Create subdirectories if needed
#                 os.makedirs(output_subdir, exist_ok=True)
#                 output_path = os.path.join(output_subdir, file)
                
#                 try:
#                     # Read and convert image
#                     img = cv2.imread(input_path)
#                     gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
                    
#                     # Save grayscale image
#                     cv2.imwrite(output_path, gray_img)
#                     # print(f"Converted: {input_path} -> {output_path}")
                    
#                 except Exception as e:
#                     print(f"Error processing {input_path}: {str(e)}")

# # Usage example
# convert_to_grayscale("RAF-DB_ResEmoteNet\\test")
# convert_to_grayscale("RAF-DB_ResEmoteNet\\train")
# convert_to_grayscale("RAF-DB_ResEmoteNet\\validation")
# Out:
# Converted: RAF-DB_ResEmoteNet\test\test_10001_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10001_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10003_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10003_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10004_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10004_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1000_Angry.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1000_Angry.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10021_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10021_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10029_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10029_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10047_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10047_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10054_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10054_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10068_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10068_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10077_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10077_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10081_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10081_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10102_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10102_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10103_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10103_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10108_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10108_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10119_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10119_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10120_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10120_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10122_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10122_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10135_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10135_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10145_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10145_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10153_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10153_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10157_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10157_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10184_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10184_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10188_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10188_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10192_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10192_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10198_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10198_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10199_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10199_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10204_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10204_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10208_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10208_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10216_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10216_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10220_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10220_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10238_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10238_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10243_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10243_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10256_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10256_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10268_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10268_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1026_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1026_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10272_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10272_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10294_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10294_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10302_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10302_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10311_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10311_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10320_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10320_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10324_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10324_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10339_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10339_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10343_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10343_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10344_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10344_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10359_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10359_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1037_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1037_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10395_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10395_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10403_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10403_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10404_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10404_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10415_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10415_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10416_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10416_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10433_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10433_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1043_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1043_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10440_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10440_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10446_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10446_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10457_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10457_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10458_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10458_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10463_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10463_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10466_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10466_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10477_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10477_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10493_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10493_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10496_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10496_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10499_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10499_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10514_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10514_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10545_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10545_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10547_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10547_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10556_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10556_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10565_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10565_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10567_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10567_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10581_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10581_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10596_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10596_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10600_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10600_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10603_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10603_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10608_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10608_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10613_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10613_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1061_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1061_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10625_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10625_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10634_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10634_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10635_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10635_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10643_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10643_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10655_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10655_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10657_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10657_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10665_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10665_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10675_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10675_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1068_Disgust.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1068_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10692_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10692_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10696_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10696_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10711_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10711_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10719_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10719_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10726_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10726_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1072_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1072_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10730_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10730_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10733_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10733_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10741_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10741_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10745_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10745_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10746_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10746_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10761_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10761_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10767_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10767_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10775_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10775_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_107_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_107_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1080_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1080_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10826_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10826_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1082_Sad.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1082_Sad.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10830_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10830_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10861_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10861_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10876_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10876_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10881_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10881_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10896_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10896_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10904_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10904_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10910_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10910_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10923_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10923_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10925_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10925_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10951_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10951_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10959_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10959_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10963_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10963_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10982_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10982_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10992_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10992_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10994_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10994_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_10996_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_10996_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11001_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11001_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11002_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11002_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1100_Sad.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1100_Sad.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11025_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11025_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1102_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1102_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11033_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11033_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11042_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11042_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11066_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11066_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11068_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11068_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11069_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11069_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11079_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11079_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1111_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1111_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11120_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11120_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11143_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11143_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11144_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11144_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11161_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11161_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11166_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11166_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11168_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11168_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11178_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11178_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11182_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11182_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11186_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11186_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11188_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11188_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1121_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1121_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11227_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11227_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11229_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11229_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11232_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11232_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11233_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11233_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11238_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11238_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11242_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11242_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11247_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11247_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11250_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11250_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11263_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11263_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11269_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11269_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11274_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11274_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11281_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11281_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11294_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11294_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1129_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1129_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11323_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11323_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11325_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11325_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11331_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11331_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11347_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11347_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11365_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11365_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11378_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11378_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11389_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11389_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11391_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11391_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11396_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11396_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11397_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11397_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11406_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11406_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11410_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11410_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11417_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11417_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11420_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11420_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11433_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11433_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11435_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11435_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11445_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11445_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11446_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11446_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11463_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11463_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11482_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11482_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11483_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11483_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11484_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11484_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11511_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11511_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11522_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11522_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11528_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11528_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1153_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1153_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11540_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11540_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11556_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11556_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11579_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11579_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1158_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1158_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11610_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11610_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11625_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11625_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11641_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11641_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11681_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11681_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1170_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1170_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1172_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1172_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11732_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11732_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11745_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11745_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1174_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1174_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11760_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11760_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11765_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11765_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11768_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11768_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11773_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11773_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11775_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11775_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11777_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11777_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11784_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11784_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11786_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11786_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11790_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11790_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11796_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11796_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11802_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11802_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11839_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11839_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11843_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11843_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11862_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11862_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11866_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11866_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1186_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1186_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11881_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11881_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11887_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11887_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11889_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11889_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11891_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11891_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11903_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11903_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1190_Angry.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1190_Angry.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11915_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11915_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1191_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1191_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11926_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11926_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11932_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11932_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11950_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11950_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11967_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11967_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11972_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11972_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1198_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1198_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11991_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11991_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_11996_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_11996_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12010_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12010_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12016_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12016_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12019_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12019_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12021_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12021_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12023_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12023_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12024_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12024_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12027_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12027_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12033_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12033_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12038_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12038_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12046_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12046_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12052_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12052_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12060_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12060_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12068_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12068_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12091_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12091_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12099_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12099_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12100_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12100_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12130_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12130_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12140_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12140_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12152_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12152_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12161_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12161_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12170_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12170_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12176_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12176_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12180_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12180_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12183_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12183_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12192_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12192_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_121_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_121_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12203_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12203_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12206_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12206_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12209_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12209_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12223_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12223_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1222_Sad.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1222_Sad.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12230_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12230_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12238_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12238_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12240_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12240_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12247_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12247_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12251_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12251_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12263_Neutral.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12263_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1229_Angry.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1229_Angry.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12303_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12303_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1230_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1230_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12321_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12321_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12324_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12324_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12328_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12328_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12336_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12336_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12359_Sad.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12359_Sad.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12360_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12360_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12382_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12382_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12439_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12439_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1243_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1243_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12440_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12440_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12462_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12462_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12466_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12466_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12470_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12470_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12476_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12476_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12481_Sad.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12481_Sad.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12494_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12494_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12496_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12496_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1249_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1249_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12519_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12519_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12533_Disgust.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12533_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12538_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12538_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12544_Fear.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12544_Fear.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12552_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12552_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1257_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1257_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12585_Sad.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12585_Sad.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12600_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12600_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12601_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12601_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12617_Angry.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12617_Angry.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12623_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12623_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12625_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12625_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12644_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12644_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12646_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12646_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1264_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1264_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12652_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12652_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12661_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12661_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12662_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12662_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12672_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12672_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12683_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12683_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12702_Disgust.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12702_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12703_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12703_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12729_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12729_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12735_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12735_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12749_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12749_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12755_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12755_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12760_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12760_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12780_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12780_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12790_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12790_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12803_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12803_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12814_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12814_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12817_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12817_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12821_Angry.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12821_Angry.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12838_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12838_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12839_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12839_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1284_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1284_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12876_Sad.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12876_Sad.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12883_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12883_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12893_Fear.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12893_Fear.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12902_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12902_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12903_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12903_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12908_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12908_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12914_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12914_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12922_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12922_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12926_Angry.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12926_Angry.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12958_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12958_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12962_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12962_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1296_Sad.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1296_Sad.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12973_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12973_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_12989_Sad.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_12989_Sad.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13039_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13039_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13041_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13041_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13045_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13045_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13047_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13047_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1304_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1304_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13055_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13055_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13066_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13066_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13071_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13071_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13108_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13108_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13121_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13121_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13129_Fear.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13129_Fear.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13133_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13133_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1313_Angry.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1313_Angry.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13148_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13148_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13149_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13149_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13164_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13164_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13177_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13177_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13183_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13183_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13193_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13193_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13198_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13198_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1320_Disgust.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1320_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13245_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13245_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13253_Angry.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13253_Angry.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13277_Angry.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13277_Angry.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1327_Sad.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1327_Sad.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1328_Sad.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1328_Sad.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13303_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13303_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13307_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13307_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13309_Disgust.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13309_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13334_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13334_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1333_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1333_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13348_Sad.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13348_Sad.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13350_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13350_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13352_Sad.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13352_Sad.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13362_Disgust.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13362_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13369_Disgust.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13369_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1336_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1336_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13386_Sad.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13386_Sad.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13401_Sad.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13401_Sad.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13404_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13404_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1340_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1340_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13424_Sad.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13424_Sad.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13426_Sad.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13426_Sad.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13429_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13429_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13431_Sad.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13431_Sad.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13436_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13436_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13440_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13440_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1344_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1344_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13457_Sad.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13457_Sad.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13468_Sad.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13468_Sad.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13488_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13488_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13492_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13492_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13494_Sad.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13494_Sad.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1350_Sad.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1350_Sad.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13515_Sad.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13515_Sad.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13518_Sad.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13518_Sad.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13534_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13534_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13537_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13537_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13549_Sad.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13549_Sad.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13551_Angry.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13551_Angry.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_1356_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_1356_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13585_Sad.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13585_Sad.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13600_Angry.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13600_Angry.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13606_Angry.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13606_Angry.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13609_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13609_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13630_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13630_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13643_Angry.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13643_Angry.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13648_Surprised.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13648_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\test\test_13654_Happy.jpg -> RAF-DB_ResEmoteNet\test_grayscale\.\test_13654_Happy.jpg
# ...
# Converted: RAF-DB_ResEmoteNet\validation\validation_9009_Surprised.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9009_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9027_Happy.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9027_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9029_Happy.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9029_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9053_Sad.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9053_Sad.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9073_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9073_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9077_Angry.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9077_Angry.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9088_Happy.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9088_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9122_Surprised.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9122_Surprised.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9125_Sad.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9125_Sad.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9135_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9135_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9136_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9136_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9139_Happy.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9139_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9147_Happy.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9147_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9154_Sad.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9154_Sad.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9158_Fear.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9158_Fear.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_915_Happy.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_915_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9193_Fear.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9193_Fear.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9195_Fear.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9195_Fear.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_921_Happy.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_921_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9220_Fear.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9220_Fear.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9229_Fear.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9229_Fear.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9248_Fear.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9248_Fear.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9257_Fear.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9257_Fear.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9261_Fear.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9261_Fear.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9263_Fear.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9263_Fear.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9267_Fear.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9267_Fear.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9280_Fear.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9280_Fear.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9283_Fear.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9283_Fear.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9293_Fear.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9293_Fear.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9301_Fear.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9301_Fear.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9328_Fear.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9328_Fear.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9341_Fear.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9341_Fear.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9343_Fear.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9343_Fear.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9344_Fear.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9344_Fear.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9365_Fear.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9365_Fear.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9368_Fear.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9368_Fear.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9371_Fear.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9371_Fear.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9383_Fear.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9383_Fear.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9389_Fear.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9389_Fear.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_938_Happy.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_938_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9404_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9404_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_942_Happy.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_942_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9437_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9437_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9458_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9458_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9470_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9470_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9472_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9472_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9478_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9478_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9484_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9484_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9489_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9489_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9493_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9493_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9495_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9495_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9498_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9498_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9499_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9499_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9508_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9508_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9526_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9526_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9539_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9539_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9547_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9547_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9548_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9548_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9550_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9550_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9552_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9552_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9557_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9557_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_955_Happy.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_955_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9572_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9572_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9578_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9578_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9586_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9586_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_958_Happy.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_958_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9602_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9602_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9607_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9607_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9622_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9622_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9623_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9623_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9629_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9629_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9645_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9645_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9647_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9647_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9651_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9651_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9653_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9653_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9654_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9654_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9656_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9656_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9682_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9682_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9698_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9698_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9725_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9725_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9737_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9737_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9745_Disgust.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9745_Disgust.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9751_Neutral.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9751_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9752_Neutral.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9752_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9757_Neutral.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9757_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9758_Neutral.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9758_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9761_Neutral.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9761_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9763_Neutral.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9763_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9771_Neutral.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9771_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9795_Neutral.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9795_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9796_Neutral.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9796_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9801_Neutral.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9801_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9827_Neutral.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9827_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9830_Neutral.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9830_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9835_Neutral.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9835_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9853_Neutral.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9853_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9865_Neutral.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9865_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_987_Happy.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_987_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9888_Neutral.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9888_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9898_Neutral.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9898_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9903_Neutral.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9903_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9904_Neutral.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9904_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9907_Neutral.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9907_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9949_Neutral.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9949_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_994_Happy.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_994_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9951_Neutral.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9951_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9953_Neutral.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9953_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9956_Neutral.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9956_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9973_Neutral.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9973_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9977_Neutral.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9977_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_997_Happy.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_997_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_998_Happy.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_998_Happy.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9992_Neutral.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9992_Neutral.jpg
# Converted: RAF-DB_ResEmoteNet\validation\validation_9994_Neutral.jpg -> RAF-DB_ResEmoteNet\validation_grayscale\.\validation_9994_Neutral.jpg

# %% [markdown]
# ### Create Label CSV File

# %%
# import os
# import csv

# # Original mapping provided
# label_mapping = {
#     1: "Surprised",
#     2: "Fear", 
#     3: "Disgust",
#     4: "Happy",
#     5: "Sad",
#     6: "Angry",
#     7: "Neutral"
# }

# # Create inverted mapping for label conversion
# emotion_to_id = {v: k for k, v in label_mapping.items()}

# def create_label_csvs(root_dir):
#     """
#     Creates CSV files with numerical labels based on filename patterns.
#     File naming convention: [prefix]_[number]_[EMOTION_NAME].jpg
#     Example: test_21_Happy.jpg → 4
#     """
#     valid_extensions = ('.jpg', '.jpeg', '.png', '.bmp')
    
#     for dirpath, _, filenames in os.walk(root_dir):
#         csv_data = []
        
#         for filename in filenames:
#             if not filename.lower().endswith(valid_extensions):
#                 continue
                
#             base_name = os.path.splitext(filename)[0]
#             parts = base_name.split('_')
            
#             if len(parts) < 3:
#                 print(f"Skipping invalid filename: {filename}")
#                 continue
                
#             # Get emotion name and convert to title case
#             emotion_name = parts[-1].capitalize()
            
#             # Convert to numerical label
#             label = emotion_to_id.get(emotion_name)
            
#             if label is None:
#                 print(f"Skipping unknown emotion: {emotion_name} in {filename}")
#                 continue
                
#             csv_data.append([filename, label])
        
#         if csv_data:
#             csv_path = os.path.join(dirpath, "labels.csv")
#             with open(csv_path, 'w', newline='') as f:
#                 writer = csv.writer(f)
#                 writer.writerow(["Image_name", "label"])
#                 writer.writerows(csv_data)
                
#             print(f"Created {csv_path} with {len(csv_data)} entries")

# # Usage
# # create_label_csvs("RAF-DB_ResEmoteNet\\test")
# # create_label_csvs("RAF-DB_ResEmoteNet\\train")
# # create_label_csvs("RAF-DB_ResEmoteNet\\validation")

# create_label_csvs("RAF-DB_ResEmoteNet\\test_grayscale")
# create_label_csvs("RAF-DB_ResEmoteNet\\train_grayscale")
# create_label_csvs("RAF-DB_ResEmoteNet\\validation_grayscale")
# Out:
# Created RAF-DB_ResEmoteNet\test_grayscale\labels.csv with 1540 entries
# Created RAF-DB_ResEmoteNet\train_grayscale\labels.csv with 13329 entries
# Created RAF-DB_ResEmoteNet\validation_grayscale\labels.csv with 1530 entries
